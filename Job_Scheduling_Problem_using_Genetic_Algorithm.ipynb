# %%
import random
import numpy as np
NUM_JOBS=6
NUM_MACHINES=3
POPULATION_SIZE=10
MUTATION_RATE=0.1
NUM_GENERATIONS=100

PROCESSING_TIMES=[random.randint(1,10) for _ in range(NUM_JOBS)]

def generate_chromosome():
    return [random.randint(0,NUM_MACHINES-1) for _ in range(NUM_JOBS)]

def initialize_population():
    return [generate_chromosome() for _ in range(POPULATION_SIZE)]

def fitness(chromosome):
    machine_times=[0]*NUM_MACHINES
    for job,machine in enumerate(chromosome):
        machine_times[machine]+=PROCESSING_TIMES[job]
    return 1/max(machine_times)

def selection(population):
    fitness_scores=[fitness(chrom) for chrom in population]
    total_fitness=sum(fitness_scores)
    probabilities=[f/total_fitness for f in fitness_scores]
    return population[np.random.choice(range(POPULATION_SIZE),p=probabilities)]

def crossover(parent1,parent2):
    point1,point2=sorted(random.sample(range(NUM_JOBS),2))
    child1=parent1[:point1]+parent2[point1:point2]+parent1[point2:]
    child2=parent2[:point1]+parent1[point1:point2]+parent2[point2:]
    return child1,child2

def mutate(chromosome):
    if random.random()<MUTATION_RATE:
        index=random.randint(0,NUM_JOBS-1)
        chromosome[index]=random.randint(0,NUM_MACHINES-1)
    return chromosome

def genetic_algorithm():
    population=initialize_population()

    for generation in range(NUM_GENERATIONS):
        new_population=[]
        for _ in range(POPULATION_SIZE//2):
            parent1,parent2=selection(population),selection(population)
            child1,child2=crossover(parent1,parent2)
            new_population.extend([mutate(child1),mutate(child2)])
        population=sorted(new_population,key=fitness,reverse=True)[:POPULATION_SIZE]
        best_fitness=fitness(population[0])
        print(f"Generation {generation+1},Best Fitness: {best_fitness:.5f}")

    return population[0]
best_schedule=genetic_algorithm()
print("Best Schedule Found:",best_schedule)
# Out:
# Generation 1,Best Fitness: 0.09091
# Generation 2,Best Fitness: 0.08333
# Generation 3,Best Fitness: 0.09091
# Generation 4,Best Fitness: 0.09091
# Generation 5,Best Fitness: 0.09091
# Generation 6,Best Fitness: 0.09091
# Generation 7,Best Fitness: 0.09091
# Generation 8,Best Fitness: 0.09091
# Generation 9,Best Fitness: 0.09091
# Generation 10,Best Fitness: 0.09091
# Generation 11,Best Fitness: 0.09091
# Generation 12,Best Fitness: 0.09091
# Generation 13,Best Fitness: 0.09091
# Generation 14,Best Fitness: 0.09091
# Generation 15,Best Fitness: 0.09091
# Generation 16,Best Fitness: 0.09091
# Generation 17,Best Fitness: 0.09091
# Generation 18,Best Fitness: 0.09091
# Generation 19,Best Fitness: 0.09091
# Generation 20,Best Fitness: 0.09091
# Generation 21,Best Fitness: 0.09091
# Generation 22,Best Fitness: 0.09091
# Generation 23,Best Fitness: 0.09091
# Generation 24,Best Fitness: 0.09091
# Generation 25,Best Fitness: 0.09091
# Generation 26,Best Fitness: 0.09091
# Generation 27,Best Fitness: 0.09091
# Generation 28,Best Fitness: 0.09091
# Generation 29,Best Fitness: 0.09091
# Generation 30,Best Fitness: 0.09091
# Generation 31,Best Fitness: 0.09091
# Generation 32,Best Fitness: 0.09091
# Generation 33,Best Fitness: 0.09091
# Generation 34,Best Fitness: 0.09091
# Generation 35,Best Fitness: 0.09091
# Generation 36,Best Fitness: 0.09091
# Generation 37,Best Fitness: 0.09091
# Generation 38,Best Fitness: 0.09091
# Generation 39,Best Fitness: 0.09091
# Generation 40,Best Fitness: 0.09091
# Generation 41,Best Fitness: 0.09091
# Generation 42,Best Fitness: 0.09091
# Generation 43,Best Fitness: 0.09091
# Generation 44,Best Fitness: 0.09091
# Generation 45,Best Fitness: 0.09091
# Generation 46,Best Fitness: 0.09091
# Generation 47,Best Fitness: 0.09091
# Generation 48,Best Fitness: 0.09091
# Generation 49,Best Fitness: 0.09091
# Generation 50,Best Fitness: 0.09091
# Generation 51,Best Fitness: 0.09091
# Generation 52,Best Fitness: 0.09091
# Generation 53,Best Fitness: 0.09091
# Generation 54,Best Fitness: 0.09091
# Generation 55,Best Fitness: 0.09091
# Generation 56,Best Fitness: 0.09091
# Generation 57,Best Fitness: 0.09091
# Generation 58,Best Fitness: 0.09091
# Generation 59,Best Fitness: 0.09091
# Generation 60,Best Fitness: 0.09091
# Generation 61,Best Fitness: 0.09091
# Generation 62,Best Fitness: 0.09091
# Generation 63,Best Fitness: 0.09091
# Generation 64,Best Fitness: 0.09091
# Generation 65,Best Fitness: 0.09091
# Generation 66,Best Fitness: 0.09091
# Generation 67,Best Fitness: 0.09091
# Generation 68,Best Fitness: 0.09091
# Generation 69,Best Fitness: 0.09091
# Generation 70,Best Fitness: 0.09091
# Generation 71,Best Fitness: 0.09091
# Generation 72,Best Fitness: 0.09091
# Generation 73,Best Fitness: 0.09091
# Generation 74,Best Fitness: 0.09091
# Generation 75,Best Fitness: 0.09091
# Generation 76,Best Fitness: 0.09091
# Generation 77,Best Fitness: 0.09091
# Generation 78,Best Fitness: 0.09091
# Generation 79,Best Fitness: 0.09091
# Generation 80,Best Fitness: 0.09091
# Generation 81,Best Fitness: 0.09091
# Generation 82,Best Fitness: 0.09091
# Generation 83,Best Fitness: 0.09091
# Generation 84,Best Fitness: 0.09091
# Generation 85,Best Fitness: 0.09091
# Generation 86,Best Fitness: 0.09091
# Generation 87,Best Fitness: 0.09091
# Generation 88,Best Fitness: 0.09091
# Generation 89,Best Fitness: 0.09091
# Generation 90,Best Fitness: 0.08333
# Generation 91,Best Fitness: 0.08333
# Generation 92,Best Fitness: 0.09091
# Generation 93,Best Fitness: 0.09091
# Generation 94,Best Fitness: 0.09091
# Generation 95,Best Fitness: 0.09091
# Generation 96,Best Fitness: 0.09091
# Generation 97,Best Fitness: 0.09091
# Generation 98,Best Fitness: 0.09091
# Generation 99,Best Fitness: 0.09091
# Generation 100,Best Fitness: 0.08333
# Best Schedule Found: [2, 1, 1, 2, 0, 2]
